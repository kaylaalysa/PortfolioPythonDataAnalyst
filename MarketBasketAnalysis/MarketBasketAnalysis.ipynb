# %% [markdown]
# # Import Libraries

# %%
import pandas as pd
import numpy as np
import datetime as dt
from scipy import stats

# %%
df = pd.read_csv('Salinan Online Retail Data.csv')

# %%
df.head()
# Out:
#   order_id product_code                     product_name  quantity  \
# 0   493410      TEST001          This is a test product.         5
# 1  C493411        21539          RETRO SPOTS BUTTER DISH        -1
# 2   493412      TEST001          This is a test product.         5
# 3   493413        21724  PANDA AND BUNNIES STICKER SHEET         1
# 4   493413        84578   ELEPHANT TOY WITH BLUE T-SHIRT         1
#
#             order_date  price  customer_id
# 0  2010-01-04 09:24:00   4.50      12346.0
# 1  2010-01-04 09:43:00   4.25      14590.0
# 2  2010-01-04 09:53:00   4.50      12346.0
# 3  2010-01-04 09:54:00   0.85          NaN
# 4  2010-01-04 09:54:00   3.75          NaN

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 461773 entries, 0 to 461772
# Data columns (total 7 columns):
#  #   Column        Non-Null Count   Dtype
# ---  ------        --------------   -----
#  0   order_id      461773 non-null  object
#  1   product_code  461773 non-null  object
#  2   product_name  459055 non-null  object
#  3   quantity      461773 non-null  int64
#  4   order_date    461773 non-null  object
#  5   price         461773 non-null  float64
#  6   customer_id   360853 non-null  float64
# dtypes: float64(2), int64(1), object(4)
# memory usage: 24.7+ MB

# %% [markdown]
# # Preprocessing Dataset - Data Cleaning

# %%
# Create column 'date'
df['date'] = pd.to_datetime(df['order_date']).dt.date
df['date'] = pd.to_datetime(df['date'])

# %%
# check null values
df.isnull().sum()
# Out:
# order_id             0
# product_code         0
# product_name      2718
# quantity             0
# order_date           0
# price                0
# customer_id     100920
# date                 0
# dtype: int64

# %%
# delete null values in 'customer_id' and 'product_name' 
df = df[~df['customer_id'].isna()]
df = df[~df['product_name'].isna()]

# %%
# convert 'customer_id' to string
df['customer_id'] = df['customer_id'].astype(str)

# %%
# lowercase 'product_name'
df['product_name'] = df['product_name'].str.lower()

# %%
# delete all rows with product_code or product_name 'test'
df = df[(~df['product_code'].str.lower().str.contains('test')) |
                    (~df['product_name'].str.contains('test '))]

# %%
# delete rows with cancelled status, namely those whose order_id starts with 'C'
df = df[df['order_id'].str[:1]!='C']

# %%
# change the negative quantity value to positive 
# because the negative value only indicates that the order is cancelled
df['quantity'] = df['quantity'].abs()

# %%
# delete rows with negative price values
df = df[df['price'] > 0 ]

# %%
# create an amount value, which is the multiplication of quantity and price
df['amount'] = df['quantity'] * df['price']

# %%
# replace the product_name of a product_code that has multiple product_names with the one that appears most often
most_freq_product_name = df.groupby(['product_code', 'product_name'], as_index=False) \
    .agg(order_cnt=('order_id', 'nunique')) \
    .sort_values(['product_code', 'order_cnt'], ascending=[True, False])

most_freq_product_name['rank'] = most_freq_product_name.groupby('product_code')['order_cnt'] \
    .rank(method='first', ascending=False)

most_freq_product_name = most_freq_product_name[most_freq_product_name['rank'] == 1] \
    .drop(columns=['order_cnt', 'rank'])

df = df.merge(most_freq_product_name.rename(columns={'product_name': 'most_freq_product_name'}), 
              how='left', on='product_code')

df['product_name'] = df['most_freq_product_name']
df = df.drop(columns='most_freq_product_name')

# %%
# delete outliers
df = df[(np.abs(stats.zscore(df[['quantity','amount']]))<3).all(axis=1)]
df = df.reset_index(drop=True)
df
# Out:
#        order_id product_code                       product_name  quantity  \
# 0        493414        21844                  red retrospot mug        36
# 1        493414        21533          retro spot large milk jug        12
# 2        493414        37508    new england ceramic cake server         2
# 3        493414       35001G               hand open shape gold         2
# 4        493414        21527   red retrospot traditional teapot        12
# ...         ...          ...                                ...       ...
# 350087   539988        84380  set of 3 butterfly cookie cutters         1
# 350088   539988       84849D              hot baths soap holder         1
# 350089   539988       84849B             fairy soap soap holder         1
# 350090   539988        22854        cream sweetheart egg holder         2
# 350091   539988       47559B                tea time oven glove         2
#
#                  order_date  price customer_id       date  amount
# 0       2010-01-04 10:28:00   2.55     14590.0 2010-01-04   91.80
# 1       2010-01-04 10:28:00   4.25     14590.0 2010-01-04   51.00
# 2       2010-01-04 10:28:00   2.55     14590.0 2010-01-04    5.10
# 3       2010-01-04 10:28:00   4.25     14590.0 2010-01-04    8.50
# 4       2010-01-04 10:28:00   6.95     14590.0 2010-01-04   83.40
# ...                     ...    ...         ...        ...     ...
# 350087  2010-12-23 16:06:00   1.25     18116.0 2010-12-23    1.25
# 350088  2010-12-23 16:06:00   1.69     18116.0 2010-12-23    1.69
# 350089  2010-12-23 16:06:00   1.69     18116.0 2010-12-23    1.69
# 350090  2010-12-23 16:06:00   4.95     18116.0 2010-12-23    9.90
# 350091  2010-12-23 16:06:00   1.25     18116.0 2010-12-23    2.50
#
# [350092 rows x 9 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 350092 entries, 0 to 350091
# Data columns (total 9 columns):
#  #   Column        Non-Null Count   Dtype
# ---  ------        --------------   -----
#  0   order_id      350092 non-null  object
#  1   product_code  350092 non-null  object
#  2   product_name  350092 non-null  object
#  3   quantity      350092 non-null  int64
#  4   order_date    350092 non-null  object
#  5   price         350092 non-null  float64
#  6   customer_id   350092 non-null  object
#  7   date          350092 non-null  datetime64[ns]
#  8   amount        350092 non-null  float64
# dtypes: datetime64[ns](1), float64(2), int64(1), object(5)
# memory usage: 24.0+ MB

# %% [markdown]
# # Dataset Basket
#
# ## Create Dataframe 'basket'

# %%
basket = pd.pivot_table(df, 
                        index='order_id', 
                        columns='product_name', 
                        values = 'product_code', 
                        aggfunc='nunique', 
                        fill_value=0)

basket
# Out:
# product_name  10 colour spaceboy pen  12 ass zinc christmas decorations  \
# order_id
# 493414                             0                                  0
# 493427                             0                                  0
# 493428                             0                                  0
# 493432                             0                                  0
# 493433                             0                                  0
# ...                              ...                                ...
# 539981                             0                                  0
# 539982                             0                                  0
# 539985                             0                                  0
# 539987                             0                                  0
# 539988                             0                                  0
#
# product_name  12 coloured party balloons  12 daisy pegs in wood box  \
# order_id
# 493414                                 0                          0
# 493427                                 0                          0
# 493428                                 0                          0
# 493432                                 0                          0
# 493433                                 0                          0
# ...                                  ...                        ...
# 539981                                 0                          0
# 539982                                 0                          0
# 539985                                 0                          0
# 539987                                 0                          0
# 539988                                 0                          0
#
# product_name  12 egg house painted wood  12 ivory rose peg place settings  \
# order_id
# 493414                                0                                 0
# 493427                                0                                 0
# 493428                                0                                 0
# 493432                                0                                 0
# 493433                                0                                 0
# ...                                 ...                               ...
# 539981                                0                                 0
# 539982                                0                                 0
# 539985                                0                                 0
# 539987                                0                                 0
# 539988                                0                                 0
#
# product_name  12 message cards with envelopes  12 mini toadstool pegs  \
# order_id
# 493414                                      0                       0
# 493427                                      0                       0
# 493428                                      0                       0
# 493432                                      0                       0
# 493433                                      0                       0
# ...                                       ...                     ...
# 539981                                      0                       0
# 539982                                      0                       0
# 539985                                      0                       0
# 539987                                      0                       0
# 539988                                      0                       0
#
# product_name  12 pencil small tube woodland  12 pencils small tube posy  ...  \
# order_id                                                                 ...
# 493414                                    0                           0  ...
# 493427                                    0                           0  ...
# 493428                                    0                           0  ...
# 493432                                    0                           0  ...
# 493433                                    0                           0  ...
# ...                                     ...                         ...  ...
# 539981                                    0                           0  ...
# 539982                                    0                           0  ...
# 539985                                    0                           0  ...
# 539987                                    0                           0  ...
# 539988                                    0                           0  ...
#
# product_name  zinc heart lattice charger large  \
# order_id
# 493414                                       0
# 493427                                       0
# 493428                                       0
# 493432                                       0
# 493433                                       0
# ...                                        ...
# 539981                                       0
# 539982                                       0
# 539985                                       0
# 539987                                       0
# 539988                                       0
#
# product_name  zinc heart lattice charger small  \
# order_id
# 493414                                       0
# 493427                                       0
# 493428                                       0
# 493432                                       0
# 493433                                       0
# ...                                        ...
# 539981                                       0
# 539982                                       0
# 539985                                       0
# 539987                                       0
# 539988                                       0
#
# product_name  zinc heart lattice double planter  \
# order_id
# 493414                                        0
# 493427                                        0
# 493428                                        0
# 493432                                        0
# 493433                                        0
# ...                                         ...
# 539981                                        0
# 539982                                        0
# 539985                                        0
# 539987                                        0
# 539988                                        0
#
# product_name  zinc heart lattice planter bowl  \
# order_id
# 493414                                      0
# 493427                                      0
# 493428                                      0
# 493432                                      0
# 493433                                      0
# ...                                       ...
# 539981                                      0
# 539982                                      0
# 539985                                      0
# 539987                                      0
# 539988                                      0
#
# product_name  zinc heart lattice t-light holder  zinc heart lattice tray oval  \
# order_id
# 493414                                        0                             0
# 493427                                        0                             0
# 493428                                        0                             0
# 493432                                        0                             0
# 493433                                        0                             0
# ...                                         ...                           ...
# 539981                                        0                             0
# 539982                                        0                             0
# 539985                                        0                             0
# 539987                                        0                             0
# 539988                                        0                             0
#
# product_name  zinc metal heart decoration  zinc police box lantern  \
# order_id
# 493414                                  0                        0
# 493427                                  0                        0
# 493428                                  0                        0
# 493432                                  0                        0
# 493433                                  0                        0
# ...                                   ...                      ...
# 539981                                  0                        0
# 539982                                  0                        0
# 539985                                  0                        0
# 539987                                  0                        0
# 539988                                  0                        0
#
# product_name  zinc top  2 door wooden shelf  zinc willie winkie  candle stick
# order_id
# 493414                                    0                                 0
# 493427                                    0                                 0
# 493428                                    0                                 0
# 493432                                    0                                 0
# 493433                                    0                                 0
# ...                                     ...                               ...
# 539981                                    0                                 0
# 539982                                    0                                 0
# 539985                                    0                                 0
# 539987                                    0                                 0
# 539988                                    0                                 0
#
# [16272 rows x 3842 columns]

# %%
basket.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 16272 entries, 493414 to 539988
# Columns: 3842 entries, 10 colour spaceboy pen to zinc willie winkie  candle stick
# dtypes: int64(3842)
# memory usage: 477.1+ MB

# %% [markdown]
# ## Encode the basket DataFrame with True for all values ​​above 0 and False for all values ​​0

# %%
def encode(x):
    if x==0:
        return False
    if x>0:
        return True

basket_encode = basket.applymap(encode)
basket_encode
# Out:
# /var/folders/h0/_lfpqmzd7sg0tt8tyqvf2wh80000gn/T/ipykernel_20486/3017338639.py:7: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   basket_encode = basket.applymap(encode)
# product_name  10 colour spaceboy pen  12 ass zinc christmas decorations  \
# order_id
# 493414                         False                              False
# 493427                         False                              False
# 493428                         False                              False
# 493432                         False                              False
# 493433                         False                              False
# ...                              ...                                ...
# 539981                         False                              False
# 539982                         False                              False
# 539985                         False                              False
# 539987                         False                              False
# 539988                         False                              False
#
# product_name  12 coloured party balloons  12 daisy pegs in wood box  \
# order_id
# 493414                             False                      False
# 493427                             False                      False
# 493428                             False                      False
# 493432                             False                      False
# 493433                             False                      False
# ...                                  ...                        ...
# 539981                             False                      False
# 539982                             False                      False
# 539985                             False                      False
# 539987                             False                      False
# 539988                             False                      False
#
# product_name  12 egg house painted wood  12 ivory rose peg place settings  \
# order_id
# 493414                            False                             False
# 493427                            False                             False
# 493428                            False                             False
# 493432                            False                             False
# 493433                            False                             False
# ...                                 ...                               ...
# 539981                            False                             False
# 539982                            False                             False
# 539985                            False                             False
# 539987                            False                             False
# 539988                            False                             False
#
# product_name  12 message cards with envelopes  12 mini toadstool pegs  \
# order_id
# 493414                                  False                   False
# 493427                                  False                   False
# 493428                                  False                   False
# 493432                                  False                   False
# 493433                                  False                   False
# ...                                       ...                     ...
# 539981                                  False                   False
# 539982                                  False                   False
# 539985                                  False                   False
# 539987                                  False                   False
# 539988                                  False                   False
#
# product_name  12 pencil small tube woodland  12 pencils small tube posy  ...  \
# order_id                                                                 ...
# 493414                                False                       False  ...
# 493427                                False                       False  ...
# 493428                                False                       False  ...
# 493432                                False                       False  ...
# 493433                                False                       False  ...
# ...                                     ...                         ...  ...
# 539981                                False                       False  ...
# 539982                                False                       False  ...
# 539985                                False                       False  ...
# 539987                                False                       False  ...
# 539988                                False                       False  ...
#
# product_name  zinc heart lattice charger large  \
# order_id
# 493414                                   False
# 493427                                   False
# 493428                                   False
# 493432                                   False
# 493433                                   False
# ...                                        ...
# 539981                                   False
# 539982                                   False
# 539985                                   False
# 539987                                   False
# 539988                                   False
#
# product_name  zinc heart lattice charger small  \
# order_id
# 493414                                   False
# 493427                                   False
# 493428                                   False
# 493432                                   False
# 493433                                   False
# ...                                        ...
# 539981                                   False
# 539982                                   False
# 539985                                   False
# 539987                                   False
# 539988                                   False
#
# product_name  zinc heart lattice double planter  \
# order_id
# 493414                                    False
# 493427                                    False
# 493428                                    False
# 493432                                    False
# 493433                                    False
# ...                                         ...
# 539981                                    False
# 539982                                    False
# 539985                                    False
# 539987                                    False
# 539988                                    False
#
# product_name  zinc heart lattice planter bowl  \
# order_id
# 493414                                  False
# 493427                                  False
# 493428                                  False
# 493432                                  False
# 493433                                  False
# ...                                       ...
# 539981                                  False
# 539982                                  False
# 539985                                  False
# 539987                                  False
# 539988                                  False
#
# product_name  zinc heart lattice t-light holder  zinc heart lattice tray oval  \
# order_id
# 493414                                    False                         False
# 493427                                    False                         False
# 493428                                    False                         False
# 493432                                    False                         False
# 493433                                    False                         False
# ...                                         ...                           ...
# 539981                                    False                         False
# 539982                                    False                         False
# 539985                                    False                         False
# 539987                                    False                         False
# 539988                                    False                         False
#
# product_name  zinc metal heart decoration  zinc police box lantern  \
# order_id
# 493414                              False                    False
# 493427                              False                    False
# 493428                              False                    False
# 493432                              False                    False
# 493433                              False                    False
# ...                                   ...                      ...
# 539981                              False                    False
# 539982                              False                    False
# 539985                              False                    False
# 539987                              False                    False
# 539988                              False                    False
#
# product_name  zinc top  2 door wooden shelf  zinc willie winkie  candle stick
# order_id
# 493414                                False                             False
# 493427                                False                             False
# 493428                                False                             False
# 493432                                False                             False
# 493433                                False                             False
# ...                                     ...                               ...
# 539981                                False                             False
# 539982                                False                             False
# 539985                                False                             False
# 539987                                False                             False
# 539988                                False                             False
#
# [16272 rows x 3842 columns]

# %%
basket_encode.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 16272 entries, 493414 to 539988
# Columns: 3842 entries, 10 colour spaceboy pen to zinc willie winkie  candle stick
# dtypes: bool(3842)
# memory usage: 59.7+ MB

# %% [markdown]
# ## Take transactions with more than 1 unique product

# %%
basket_filter = basket_encode[(basket_encode>0).sum(axis=1)>1]
basket_filter
# Out:
# product_name  10 colour spaceboy pen  12 ass zinc christmas decorations  \
# order_id
# 493414                         False                              False
# 493427                         False                              False
# 493428                         False                              False
# 493432                         False                              False
# 493433                         False                              False
# ...                              ...                                ...
# 539978                         False                              False
# 539981                         False                              False
# 539982                         False                              False
# 539985                         False                              False
# 539988                         False                              False
#
# product_name  12 coloured party balloons  12 daisy pegs in wood box  \
# order_id
# 493414                             False                      False
# 493427                             False                      False
# 493428                             False                      False
# 493432                             False                      False
# 493433                             False                      False
# ...                                  ...                        ...
# 539978                             False                      False
# 539981                             False                      False
# 539982                             False                      False
# 539985                             False                      False
# 539988                             False                      False
#
# product_name  12 egg house painted wood  12 ivory rose peg place settings  \
# order_id
# 493414                            False                             False
# 493427                            False                             False
# 493428                            False                             False
# 493432                            False                             False
# 493433                            False                             False
# ...                                 ...                               ...
# 539978                            False                             False
# 539981                            False                             False
# 539982                            False                             False
# 539985                            False                             False
# 539988                            False                             False
#
# product_name  12 message cards with envelopes  12 mini toadstool pegs  \
# order_id
# 493414                                  False                   False
# 493427                                  False                   False
# 493428                                  False                   False
# 493432                                  False                   False
# 493433                                  False                   False
# ...                                       ...                     ...
# 539978                                  False                   False
# 539981                                  False                   False
# 539982                                  False                   False
# 539985                                  False                   False
# 539988                                  False                   False
#
# product_name  12 pencil small tube woodland  12 pencils small tube posy  ...  \
# order_id                                                                 ...
# 493414                                False                       False  ...
# 493427                                False                       False  ...
# 493428                                False                       False  ...
# 493432                                False                       False  ...
# 493433                                False                       False  ...
# ...                                     ...                         ...  ...
# 539978                                False                       False  ...
# 539981                                False                       False  ...
# 539982                                False                       False  ...
# 539985                                False                       False  ...
# 539988                                False                       False  ...
#
# product_name  zinc heart lattice charger large  \
# order_id
# 493414                                   False
# 493427                                   False
# 493428                                   False
# 493432                                   False
# 493433                                   False
# ...                                        ...
# 539978                                   False
# 539981                                   False
# 539982                                   False
# 539985                                   False
# 539988                                   False
#
# product_name  zinc heart lattice charger small  \
# order_id
# 493414                                   False
# 493427                                   False
# 493428                                   False
# 493432                                   False
# 493433                                   False
# ...                                        ...
# 539978                                   False
# 539981                                   False
# 539982                                   False
# 539985                                   False
# 539988                                   False
#
# product_name  zinc heart lattice double planter  \
# order_id
# 493414                                    False
# 493427                                    False
# 493428                                    False
# 493432                                    False
# 493433                                    False
# ...                                         ...
# 539978                                    False
# 539981                                    False
# 539982                                    False
# 539985                                    False
# 539988                                    False
#
# product_name  zinc heart lattice planter bowl  \
# order_id
# 493414                                  False
# 493427                                  False
# 493428                                  False
# 493432                                  False
# 493433                                  False
# ...                                       ...
# 539978                                  False
# 539981                                  False
# 539982                                  False
# 539985                                  False
# 539988                                  False
#
# product_name  zinc heart lattice t-light holder  zinc heart lattice tray oval  \
# order_id
# 493414                                    False                         False
# 493427                                    False                         False
# 493428                                    False                         False
# 493432                                    False                         False
# 493433                                    False                         False
# ...                                         ...                           ...
# 539978                                    False                         False
# 539981                                    False                         False
# 539982                                    False                         False
# 539985                                    False                         False
# 539988                                    False                         False
#
# product_name  zinc metal heart decoration  zinc police box lantern  \
# order_id
# 493414                              False                    False
# 493427                              False                    False
# 493428                              False                    False
# 493432                              False                    False
# 493433                              False                    False
# ...                                   ...                      ...
# 539978                              False                    False
# 539981                              False                    False
# 539982                              False                    False
# 539985                              False                    False
# 539988                              False                    False
#
# product_name  zinc top  2 door wooden shelf  zinc willie winkie  candle stick
# order_id
# 493414                                False                             False
# 493427                                False                             False
# 493428                                False                             False
# 493432                                False                             False
# 493433                                False                             False
# ...                                     ...                               ...
# 539978                                False                             False
# 539981                                False                             False
# 539982                                False                             False
# 539985                                False                             False
# 539988                                False                             False
#
# [15004 rows x 3842 columns]

# %%
basket_filter.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 15004 entries, 493414 to 539988
# Columns: 3842 entries, 10 colour spaceboy pen to zinc willie winkie  candle stick
# dtypes: bool(3842)
# memory usage: 55.1+ MB

# %% [markdown]
# # Implementing The Apriori Algorithm
#
# ## Install Library

# %%
# !pip install mlxtend
# Out:
# Collecting mlxtend
#   Downloading mlxtend-0.23.4-py3-none-any.whl.metadata (7.3 kB)
# Requirement already satisfied: scipy>=1.2.1 in /opt/homebrew/lib/python3.11/site-packages (from mlxtend) (1.11.1)
# Requirement already satisfied: numpy>=1.16.2 in /opt/homebrew/lib/python3.11/site-packages (from mlxtend) (1.24.3)
# Requirement already satisfied: pandas>=0.24.2 in /opt/homebrew/lib/python3.11/site-packages (from mlxtend) (2.1.4)
# Collecting scikit-learn>=1.3.1 (from mlxtend)
#   Downloading scikit_learn-1.6.1-cp311-cp311-macosx_12_0_arm64.whl.metadata (31 kB)
# Requirement already satisfied: matplotlib>=3.0.0 in /opt/homebrew/lib/python3.11/site-packages (from mlxtend) (3.7.2)
# Requirement already satisfied: joblib>=0.13.2 in /opt/homebrew/lib/python3.11/site-packages (from mlxtend) (1.3.1)
# Requirement already satisfied: contourpy>=1.0.1 in /opt/homebrew/lib/python3.11/site-packages (from matplotlib>=3.0.0->mlxtend) (1.1.0)
# Requirement already satisfied: cycler>=0.10 in /opt/homebrew/lib/python3.11/site-packages (from matplotlib>=3.0.0->mlxtend) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in /opt/homebrew/lib/python3.11/site-packages (from matplotlib>=3.0.0->mlxtend) (4.41.1)
# Requirement already satisfied: kiwisolver>=1.0.1 in /opt/homebrew/lib/python3.11/site-packages (from matplotlib>=3.0.0->mlxtend) (1.4.4)
# Requirement already satisfied: packaging>=20.0 in /opt/homebrew/lib/python3.11/site-packages (from matplotlib>=3.0.0->mlxtend) (23.1)
# Requirement already satisfied: pillow>=6.2.0 in /opt/homebrew/lib/python3.11/site-packages (from matplotlib>=3.0.0->mlxtend) (10.0.0)
# Requirement already satisfied: pyparsing<3.1,>=2.3.1 in /opt/homebrew/lib/python3.11/site-packages (from matplotlib>=3.0.0->mlxtend) (3.0.9)
# Requirement already satisfied: python-dateutil>=2.7 in /opt/homebrew/lib/python3.11/site-packages (from matplotlib>=3.0.0->mlxtend) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /opt/homebrew/lib/python3.11/site-packages (from pandas>=0.24.2->mlxtend) (2023.3)
# Requirement already satisfied: tzdata>=2022.1 in /opt/homebrew/lib/python3.11/site-packages (from pandas>=0.24.2->mlxtend) (2023.3)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /opt/homebrew/lib/python3.11/site-packages (from scikit-learn>=1.3.1->mlxtend) (3.2.0)
# Requirement already satisfied: six>=1.5 in /opt/homebrew/lib/python3.11/site-packages (from python-dateutil>=2.7->matplotlib>=3.0.0->mlxtend) (1.16.0)
# Downloading mlxtend-0.23.4-py3-none-any.whl (1.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.4/1.4 MB 7.3 MB/s eta 0:00:0000:0100:01
# Downloading scikit_learn-1.6.1-cp311-cp311-macosx_12_0_arm64.whl (11.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 11.1/11.1 MB 2.4 MB/s eta 0:00:0000:0100:01
# Installing collected packages: scikit-learn, mlxtend
#   Attempting uninstall: scikit-learn
#     Found existing installation: scikit-learn 1.3.0
#     Uninstalling scikit-learn-1.3.0:
#       Successfully uninstalled scikit-learn-1.3.0
# Successfully installed mlxtend-0.23.4 scikit-learn-1.6.1
#
# [notice] A new release of pip is available: 24.0 -> 25.0.1
# [notice] To update, run: python3.11 -m pip install --upgrade pip

# %% [markdown]
# ## Import Libraries

# %%
from mlxtend.frequent_patterns import apriori
from mlxtend.frequent_patterns import association_rules

# %% [markdown]
# ## Create a frequent itemset list (a collection of products that are frequently purchased)

# %%
frequent_itemset = apriori(basket_filter, 
                           min_support=.01, 
                           use_colnames=True).sort_values('support', ascending=False).reset_index(drop=True)

frequent_itemset['product_cnt'] = frequent_itemset['itemsets'].apply(lambda x: len(x))
frequent_itemset
# Out:
#        support                                           itemsets  product_cnt
# 0     0.177953               (white hanging heart t-light holder)            1
# 1     0.099440                         (regency cakestand 3 tier)            1
# 2     0.096841                          (jumbo bag red retrospot)            1
# 3     0.079912                 (pack of 72 retro spot cake cases)            1
# 4     0.078512                    (assorted colour bird ornament)            1
# ...        ...                                                ...          ...
# 1189  0.010064  (key fob , front  door , key fob , shed, key f...            3
# 1190  0.010064                            (wrap,suki and friends)            1
# 1191  0.010064                    (retrospot padded seat cushion)            1
# 1192  0.010064  (pack of 6 pannetone gift boxes, pack of 6 bir...            2
# 1193  0.010064  (jumbo storage bag suki, lunch bag red spotty,...            3
#
# [1194 rows x 3 columns]

# %% [markdown]
# ## Calculate the support, confidence, and lift values ​​of each possible product pair.

# %%
product_association = association_rules(
                                            frequent_itemset, 
                                            metric='confidence', 
                                            min_threshold=0.7
                                        ).sort_values(
                                            ['support', 'confidence'], 
                                            ascending=[False, False]
                                        ).reset_index(drop=True)

product_association
# Out:
#                                           antecedents  \
# 0                  (red hanging heart t-light holder)
# 1                    (sweetheart ceramic trinket box)
# 2                                 (toilet metal sign)
# 3                      (red retrospot sugar jam bowl)
# 4                      (painted metal pears assorted)
# ..                                                ...
# 81  (blue 3 piece mini dots cutlery set, green 3 p...
# 82  (green 3 piece mini dots cutlery set, pink 3 p...
# 83     (key fob , front  door , key fob , back door )
# 84  (poppy's playhouse livingroom, poppy's playhou...
# 85  (lunch bag  black skull., lunch bag suki  desi...
#
#                              consequents  antecedent support  \
# 0   (white hanging heart t-light holder)            0.058784
# 1       (strawberry ceramic trinket box)            0.049254
# 2                  (bathroom metal sign)            0.026993
# 3         (red retrospot small milk jug)            0.023660
# 4        (assorted colour bird ornament)            0.021927
# ..                                   ...                 ...
# 81  (pink 3 piece mini dots cutlery set)            0.011464
# 82  (blue 3 piece mini dots cutlery set)            0.011997
# 83                      (key fob , shed)            0.012463
# 84          (poppy's playhouse bathroom)            0.013730
# 85                (lunch bag red spotty)            0.013796
#
#     consequent support   support  confidence       lift  representativity  \
# 0             0.177953  0.042455    0.722222   4.058510               1.0
# 1             0.074980  0.037457    0.760487  10.142533               1.0
# 2             0.040589  0.021728    0.804938  19.831353               1.0
# 3             0.037123  0.016796    0.709859  19.121592               1.0
# 4             0.078512  0.016596    0.756839   9.639738               1.0
# ..                 ...       ...         ...        ...               ...
# 81            0.029992  0.010064    0.877907  29.271370               1.0
# 82            0.030525  0.010064    0.838889  27.481853               1.0
# 83            0.025060  0.010064    0.807487  32.222153               1.0
# 84            0.010997  0.010064    0.733010  66.655016               1.0
# 85            0.075913  0.010064    0.729469   9.609260               1.0
#
#     leverage  conviction  zhangs_metric   jaccard  certainty  kulczynski
# 0   0.031995    2.959371       0.800671  0.218525   0.662090    0.480400
# 1   0.033764    3.862089       0.948103  0.431644   0.741073    0.630021
# 2   0.020632    4.918499       0.975918  0.473837   0.796686    0.670121
# 3   0.015917    3.318652       0.970669  0.381818   0.698673    0.581141
# 4   0.014874    3.789618       0.916356  0.197933   0.736121    0.484107
# ..       ...         ...            ...       ...        ...         ...
# 81  0.009720    7.944827       0.977037  0.320594   0.874132    0.606731
# 82  0.009698    6.017430       0.975313  0.310062   0.833816    0.584292
# 83  0.009752    5.064272       0.981194  0.366505   0.802538    0.604541
# 84  0.009913    3.704266       0.998709  0.686364   0.730041    0.824081
# 85  0.009017    3.415821       0.908467  0.126360   0.707245    0.431021
#
# [86 rows x 14 columns]

# %%
product_association.head()
# Out:
#                           antecedents                           consequents  \
# 0  (red hanging heart t-light holder)  (white hanging heart t-light holder)
# 1    (sweetheart ceramic trinket box)      (strawberry ceramic trinket box)
# 2                 (toilet metal sign)                 (bathroom metal sign)
# 3      (red retrospot sugar jam bowl)        (red retrospot small milk jug)
# 4      (painted metal pears assorted)       (assorted colour bird ornament)
#
#    antecedent support  consequent support   support  confidence       lift  \
# 0            0.058784            0.177953  0.042455    0.722222   4.058510
# 1            0.049254            0.074980  0.037457    0.760487  10.142533
# 2            0.026993            0.040589  0.021728    0.804938  19.831353
# 3            0.023660            0.037123  0.016796    0.709859  19.121592
# 4            0.021927            0.078512  0.016596    0.756839   9.639738
#
#    representativity  leverage  conviction  zhangs_metric   jaccard  certainty  \
# 0               1.0  0.031995    2.959371       0.800671  0.218525   0.662090
# 1               1.0  0.033764    3.862089       0.948103  0.431644   0.741073
# 2               1.0  0.020632    4.918499       0.975918  0.473837   0.796686
# 3               1.0  0.015917    3.318652       0.970669  0.381818   0.698673
# 4               1.0  0.014874    3.789618       0.916356  0.197933   0.736121
#
#    kulczynski
# 0    0.480400
# 1    0.630021
# 2    0.670121
# 3    0.581141
# 4    0.484107
